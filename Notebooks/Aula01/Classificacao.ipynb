# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import statsmodels.api as sm
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from scipy import stats
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn import tree
import graphviz
from sklearn.neighbors import DistanceMetric, KNeighborsClassifier
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Classificação

# %% [markdown]
# ## Carregando os dados

# %%
Train_Data = pd.read_csv("../../Datasets/heart.csv")
Train_Data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %% [markdown]
# ## Descrição das colunas

# %% [markdown]
# 1. __Age__ is the age of candidate.
# 2. __Sex__ has numeric values. 1 denotes male and 0 denotes female.
# 3. __Chest Pain__ pain has values between 0-3. The types of angina that are described in the research paper. The higher the number, the lesser are the odds of heart attack.
# 4. __Resting blood pressure__ is normal pressure with no exercise.
# 5. __Cholesterol__ means the blockage for blood supply in the blood vessels.
# 6. __Fasting Blood Pressure__ is blood sugar taken after a long gap between a meal and the test. Typically, it's taken before any meal in the morning. 1 denotes > 120 mg/dl
# 7. __Rest ECG (electrocardiographic) results__ means ECG values taken while person is on rest which means no exercise and normal functioning of heart is happening. Values 0,1,2.
# 8. __The Maximum Heart Rate achieved__.
# 9. __Exercise induced angina__ is chest pain while exercising or doing any physical activity. 1 denotes presence and 0 denotes absence.
# 10. __Oldpeak__ = ST Depression induced by exercise relative to rest. ST Depression is the difference between value of ECG at rest and after exercise.
# 11. __ST Slope__ is the tangent to the depression value.
# 12. __The number of major blood vessels (0-3) supplying blood to heart blocked__.
# 13. __The Types of thalassemia__.
# 14. __Heart attack prediction__ where 1 denotes Heart attack occured and 0 where it din't take occur.

# %%
Train_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [markdown]
# ## Checar se as classes estão balanceadas

# %%
Train_Data['target'].value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %% [markdown]
# ## Checar se existem dados duplicados

# %%
print("Duplicated values: ", Train_Data.duplicated().sum())
duplicate = Train_Data[Train_Data.duplicated()]
duplicate
# Out:
# Duplicated values:  1
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 164   38    1   2       138   175    0        1      173      0      0.0
#
#      slope  ca  thal  target
# 164      2   4     2       1

# %% [markdown]
# ### Remover dados duplicados, deixando apenas a primeira ocorrência

# %%
Train_Data.drop_duplicates(keep='first',inplace=True) 
Train_Data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [302 rows x 14 columns]

# %% [markdown]
# ## Checar se existem dados faltantes

# %%
print("Missing values: ", Train_Data.isnull().sum().sum())
# Out:
# Missing values:  0

# %% [markdown]
# ## Checar se existem correlações entre os atributos e a saída

# %%
corr = Train_Data.corr()
corr.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_0c5e5_row0_col0, #T_0c5e5_row1_col1, #T_0c5e5_row2_col2, #T_0c5e5_row3_col3, #T_0c5e5_row4_col4, #T_0c5e5_row5_col5, #T_0c5e5_row6_col6, #T_0c5e5_row7_col7, #T_0c5e5_row8_col8, #T_0c5e5_row9_col9, #T_0c5e5_row10_col10, #T_0c5e5_row11_col11, #T_0c5e5_row12_col12, #T_0c5e5_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_0c5e5_row0_col1 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_0c5e5_row0_col2, #T_0c5e5_row2_col0, #T_0c5e5_row4_col3, #T_0c5e5_row11_col4 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_0c5e5_row0_col3, #T_0c5e5_row11_col12 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_0c5e5_row0_col4 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_0c5e5_row0_col5, #T_0c5e5_row7_col1, #T_0c5e5_row7_col12, #T_0c5e5_row8_col3 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_0c5e5_row0_col6 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_0c5e5_row0_col7, #T_0c5e5_row1_col4, #T_0c5e5_row4_col6, #T_0c5e5_row6_col5, #T_0c5e5_row7_col0, #T_0c5e5_row8_col2, #T_0c5e5_row8_col13, #T_0c5e5_row9_col10, #T_0c5e5_row10_col9, #T_0c5e5_row13_col1, #T_0c5e5_row13_col3, #T_0c5e5_row13_col8, #T_0c5e5_row13_col11, #T_0c5e5_row13_col12 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_
col13 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_0c5e5_row10_col1 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_0c5e5_row10_col3, #T_0c5e5_row10_col5 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_0c5e5_row10_col4 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_0c5e5_row10_col6, #T_0c5e5_row11_col5 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }

# %% [markdown]
# ## Dividir atributos e saída

# %%
X=Train_Data[Train_Data.columns[Train_Data.columns!='target']]
X.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal
# 0   0     1
# 1   0     2
# 2   0     2
# 3   0     2
# 4   0     2

# %%
Y=Train_Data['target']

# %% [markdown]
# ## Separar treinamento e teste

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %% [markdown]
# ## Resultados a serem imprimidos

# %%
def results(y_test,y_pred):
    results = confusion_matrix(y_test, y_pred)
    print ('Confusion Matrix :')
    print(results)
    accuracy = accuracy_score(y_test, y_pred)
    print("Accuracy: %.2f%%" % (accuracy * 100.0))
    print ('Report : ')
    print (classification_report(y_test, y_pred))

# %% [markdown]
# ## Árvore de decisão

# %%
def computeClassificationDecisionTree(X_train, X_test, y_train, y_test,printResults):
    
    arvore_classificacao = tree.DecisionTreeClassifier()
    arvore_classificacao.fit(X_train,y_train)
    y_pred = arvore_classificacao.predict(X_test)
    if printResults:
        results(y_test, y_pred)
    return y_pred,arvore_classificacao

# %%
y_pred,arvore_classificacao = computeClassificationDecisionTree(X_train, X_test, y_train, y_test, True)
# Out:
# Confusion Matrix :
# [[22  5]
#  [ 8 26]]
# Accuracy: 78.69%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.73      0.81      0.77        27
#            1       0.84      0.76      0.80        34
#
#     accuracy                           0.79        61
#    macro avg       0.79      0.79      0.79        61
# weighted avg       0.79      0.79      0.79        61

# %% [markdown]
# ### Plotando as regras criadas

# %%
dot_data = tree.export_graphviz(arvore_classificacao, out_file=None)

# %%
graph = graphviz.Source(dot_data)
graph.render("heart")
# Out:
# 'heart.pdf'

# %%
X_train.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal'],
#       dtype='object')

# %%
dot_data = tree.export_graphviz(arvore_classificacao, out_file=None, 
                      feature_names=X_train.columns,  
                      class_names=['não infarto','infarto'],  
                      filled=True, rounded=True,  
                      special_characters=True)  
graph = graphviz.Source(dot_data)

# %%
graph

# %%
graph.render("heart2")
# Out:
# 'heart2.pdf'

# %% [markdown]
# ## KNN

# %%
def compute_knn(X_train, X_test, y_train, y_test, k_neighbors):

    neigh = KNeighborsClassifier(n_neighbors=k_neighbors, metric = 'euclidean', algorithm='auto')
    neigh.fit(X_train, y_train)
    y_pred = neigh.predict(X_test)

    results(y_test, y_pred)
    
    return y_pred

# %%
y_pred = compute_knn(X_train, X_test, y_train, y_test, 3)
# Out:
# Confusion Matrix :
# [[13 14]
#  [11 23]]
# Accuracy: 59.02%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.54      0.48      0.51        27
#            1       0.62      0.68      0.65        34
#
#     accuracy                           0.59        61
#    macro avg       0.58      0.58      0.58        61
# weighted avg       0.59      0.59      0.59        61

# %%
def error_plot(X_train, X_test, y_train, y_test):

    error = []

    # Calculando o erro variando o k de 1 a 30
    for k in range(1, 30, 2):
        pred_i = compute_knn(X_train, X_test, y_train, y_test, k)
        
        error.append(np.mean(pred_i != y_test))
        
    plt.figure(figsize=(12, 6))
    plt.plot(range(1, 30, 2), error, color='red', linestyle='dashed', marker='o',
             markerfacecolor='blue', markersize=10)
    plt.title('Error Rate K Value')
    plt.xlabel('K Value')
    plt.ylabel('Mean Error')

# %%
error_plot(X_train, X_test, y_train, y_test)
# Out:
# Confusion Matrix :
# [[15 12]
#  [13 21]]
# Accuracy: 59.02%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.54      0.56      0.55        27
#            1       0.64      0.62      0.63        34
#
#     accuracy                           0.59        61
#    macro avg       0.59      0.59      0.59        61
# weighted avg       0.59      0.59      0.59        61
#
# Confusion Matrix :
# [[13 14]
#  [11 23]]
# Accuracy: 59.02%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.54      0.48      0.51        27
#            1       0.62      0.68      0.65        34
#
#     accuracy                           0.59        61
#    macro avg       0.58      0.58      0.58        61
# weighted avg       0.59      0.59      0.59        61
#
# Confusion Matrix :
# [[12 15]
#  [10 24]]
# Accuracy: 59.02%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.55      0.44      0.49        27
#            1       0.62      0.71      0.66        34
#
#     accuracy                           0.59        61
#    macro avg       0.58      0.58      0.57        61
# weighted avg       0.58      0.59      0.58        61
#
# Confusion Matrix :
# [[15 12]
#  [11 23]]
# Accuracy: 62.30%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.58      0.56      0.57        27
#            1       0.66      0.68      0.67        34
#
#     accuracy                           0.62        61
#    macro avg       0.62      0.62      0.62        61
# weighted avg       0.62      0.62      0.62        61
#
# Confusion Matrix :
# [[15 12]
#  [ 9 25]]
# Accuracy: 65.57%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.62      0.56      0.59        27
#            1       0.68      0.74      0.70        34
#
#     accuracy                           0.66        61
#    macro avg       0.65      0.65      0.65        61
# weighted avg       0.65      0.66      0.65        61
#
# Confusion Matrix :
# [[18  9]
#  [10 24]]
# Accuracy: 68.85%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.64      0.67      0.65        27
#            1       0.73      0.71      0.72        34
#
#     accuracy                           0.69        61
#    macro avg       0.69      0.69      0.69        61
# weighted avg       0.69      0.69      0.69        61
#
# Confusion Matrix :
# [[18  9]
#  [10 24]]
# Accuracy: 68.85%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.64      0.67      0.65        27
#            1       0.73      0.71      0.72        34
#
#     accuracy                           0.69        61
#    macro avg       0.69      0.69      0.69        61
# weighted avg       0.69      0.69      0.69        61
#
# Confusion Matrix :
# [[17 10]
#  [10 24]]
# Accuracy: 67.21%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.63      0.63      0.63        27
#            1       0.71      0.71      0.71        34
#
#     accuracy                           0.67        61
#    macro avg       0.67      0.67      0.67        61
# weighted avg       0.67      0.67      0.67        61
#
# Confusion Matrix :
# [[17 10]
#  [10 24]]
# Accuracy: 67.21%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.63      0.63      0.63        27
#            1       0.71      0.71      0.71        34
#
#     accuracy                           0.67        61
#    macro avg       0.67      0.67      0.67        61
# weighted avg       0.67      0.67      0.67        61
#
# Confusion Matrix :
# [[18  9]
#  [10 24]]
# Accuracy: 68.85%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.64      0.67      0.65        27
#            1       0.73      0.71      0.72        34
#
#     accuracy                           0.69        61
#    macro avg       0.69      0.69      0.69        61
# weighted avg       0.69      0.69      0.69        61
#
# Confusion Matrix :
# [[17 10]
#  [10 24]]
# Accuracy: 67.21%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.63      0.63      0.63        27
#            1       0.71      0.71      0.71        34
#
#     accuracy                           0.67        61
#    macro avg       0.67      0.67      0.67        61
# weighted avg       0.67      0.67      0.67        61
#
# Confusion Matrix :
# [[19  8]
#  [ 9 25]]
# Accuracy: 72.13%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.68      0.70      0.69        27
#            1       0.76      0.74      0.75        34
#
#     accuracy                           0.72        61
#    macro avg       0.72      0.72      0.72        61
# weighted avg       0.72      0.72      0.72        61
#
# Confusion Matrix :
# [[17 10]
#  [ 8 26]]
# Accuracy: 70.49%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.68      0.63      0.65        27
#            1       0.72      0.76      0.74        34
#
#     accuracy                           0.70        61
#    macro avg       0.70      0.70      0.70        61
# weighted avg       0.70      0.70      0.70        61
#
# Confusion Matrix :
# [[17 10]
#  [ 8 26]]
# Accuracy: 70.49%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.68      0.63      0.65        27
#            1       0.72      0.76      0.74        34
#
#     accuracy                           0.70        61
#    macro avg       0.70      0.70      0.70        61
# weighted avg       0.70      0.70      0.70        61
#
# Confusion Matrix :
# [[17 10]
#  [ 8 26]]
# Accuracy: 70.49%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.68      0.63      0.65        27
#            1       0.72      0.76      0.74        34
#
#     accuracy                           0.70        61
#    macro avg       0.70      0.70      0.70        61
# weighted avg       0.70      0.70      0.70        61

# %% [markdown]
# # KNN com dados normalizados

# %%
def compute_knn_normalized(X_train, X_test, y_train, y_test, k_neighbors):

    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)

    neigh = KNeighborsClassifier(n_neighbors=k_neighbors, metric = 'euclidean', algorithm='auto')
    neigh.fit(X_train, y_train)
    y_pred = neigh.predict(X_test)

    results(y_test, y_pred)
    return y_pred

# %%
y_pred = compute_knn_normalized(X_train, X_test, y_train, y_test, 3)
# Out:
# Confusion Matrix :
# [[26  1]
#  [ 4 30]]
# Accuracy: 91.80%
# Report :
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91        27
#            1       0.97      0.88      0.92        34
#
#     accuracy                           0.92        61
#    macro avg       0.92      0.92      0.92        61
# weighted avg       0.92      0.92      0.92        61
