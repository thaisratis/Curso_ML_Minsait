# %% [markdown]
# # Importação das bibliotecas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn import metrics
from sklearn.model_selection import train_test_split
from tensorflow import keras
import tensorflow as tf
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report 


tf.get_logger().setLevel('WARNING')

# %% [markdown]
# # Carregando os dados

# %%
Train_Data = pd.read_csv("../../Datasets/heart.csv")
Train_Data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %% [markdown]
# ## Descrição das colunas

# %% [markdown]
# 1. __Age__ is the age of candidate.
# 2. __Sex__ has numeric values. 1 denotes male and 0 denotes female.
# 3. __Chest Pain__ pain has values between 0-3. The types of angina that are described in the research paper. The higher the number, the lesser are the odds of heart attack.
# 4. __Resting blood pressure__ is normal pressure with no exercise.
# 5. __Cholesterol__ means the blockage for blood supply in the blood vessels.
# 6. __Fasting Blood Pressure__ is blood sugar taken after a long gap between a meal and the test. Typically, it's taken before any meal in the morning. 1 denotes > 120 mg/dl
# 7. __Rest ECG (electrocardiographic) results__ means ECG values taken while person is on rest which means no exercise and normal functioning of heart is happening. Values 0,1,2.
# 8. __The Maximum Heart Rate achieved__.
# 9. __Exercise induced angina__ is chest pain while exercising or doing any physical activity. 1 denotes presence and 0 denotes absence.
# 10. __Oldpeak__ = ST Depression induced by exercise relative to rest. ST Depression is the difference between value of ECG at rest and after exercise.
# 11. __ST Slope__ is the tangent to the depression value.
# 12. __The number of major blood vessels (0-3) supplying blood to heart blocked__.
# 13. __The Types of thalassemia__.
# 14. __Heart attack prediction__ where 1 denotes Heart attack occured and 0 where it din't take occur.

# %%
Train_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [markdown]
# # Checar se as classes estão balanceadas

# %%
Train_Data['target'].value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %% [markdown]
# # Checar se existem dados duplicados

# %%
print("Duplicated values: ", Train_Data.duplicated().sum())
duplicate = Train_Data[Train_Data.duplicated()]
duplicate
# Out:
# Duplicated values:  1
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 164   38    1   2       138   175    0        1      173      0      0.0
#
#      slope  ca  thal  target
# 164      2   4     2       1

# %% [markdown]
# ### Remover dados duplicados, deixando apenas a primeira ocorrência

# %%
Train_Data.drop_duplicates(keep='first',inplace=True) 
Train_Data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [302 rows x 14 columns]

# %% [markdown]
# # Checar se existem dados faltantes

# %%
print("Missing values: ", Train_Data.isnull().sum().sum())
# Out:
# Missing values:  0

# %% [markdown]
# # Checar se existem correlações entre os atributos e a saída

# %%
corr = Train_Data.corr()
corr.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_12050_row0_col0, #T_12050_row1_col1, #T_12050_row2_col2, #T_12050_row3_col3, #T_12050_row4_col4, #T_12050_row5_col5, #T_12050_row6_col6, #T_12050_row7_col7, #T_12050_row8_col8, #T_12050_row9_col9, #T_12050_row10_col10, #T_12050_row11_col11, #T_12050_row12_col12, #T_12050_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_12050_row0_col1 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_12050_row0_col2, #T_12050_row2_col0, #T_12050_row4_col3, #T_12050_row11_col4 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_12050_row0_col3, #T_12050_row11_col12 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_12050_row0_col4 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_12050_row0_col5, #T_12050_row7_col1, #T_12050_row7_col12, #T_12050_row8_col3 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_12050_row0_col6 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_12050_row0_col7, #T_12050_row1_col4, #T_12050_row4_col6, #T_12050_row6_col5, #T_12050_row7_col0, #T_12050_row8_col2, #T_12050_row8_col13, #T_12050_row9_col10, #T_12050_row10_col9, #T_12050_row13_col1, #T_12050_row13_col3, #T_12050_row13_col8, #T_12050_row13_col11, #T_12050_row13_col12 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_12050_row0_col8, #T_12050_row1_col11, #T_12050_row5_col0, #T_12050_row5_col9 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_12050_row0_col9, #T_12050_row11_col0, #T_12050_row12_col9 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_12050_row0_col10 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_12050_row0_col11 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_12050_row0_col12, #T_12050_row3_col12 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_12050_row0_col13, #T_12050_row2_col11, #T_12050_row7_col9 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_12050_row1_col0, #T_12050_row8_col4, #T_12050_row12_col7 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_12050_row1_col2, #T_12050_row12_col4 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_12050_row1_col3, #T_12050_row1_col6 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_12050_row1_col5, #T_12050_row11_col7, #T_12050_row12_col6 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_12050_row1_col7, #T_12050_row3_col7, #T_12050_row4_col13, #T_12050_row6_col12, #T_12050_row13_col6 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_12050_row1_col8, #T_12050_row12_col11 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_12050_row1_col9 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_12050_row1_col10 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_12050_row1_col12, #T_12050_row9_col12 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_12050_row1_col13 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_12050_row2_col1, #T_12050_row12_col3 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_12050_row2_col3 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_12050_row2_col4 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_12050_row2_col5, #T_12050_row2_col6, #T_12050_row7_col6, #T_12050_row10_col0, #T_12050_row12_col2 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_12050_row2_col7, #T_12050_row7_col2 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_12050_row2_col8, #T_12050_row3_col6 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_12050_row2_col9 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_12050_row2_col10 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_12050_row2_col12 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_12050_row2_col13 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_12050_row3_col0 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_12050_row3_col1, #T_12050_row9_col2, #T_12050_row10_col12 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_12050_row3_col2, #T_12050_row6_col7 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_12050_row3_col4 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_12050_row3_col5 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_12050_row3_col8, #T_12050_row4_col8, #T_12050_row5_col2, #T_12050_row8_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_12050_row3_col9 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_12050_row3_col10 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_12050_row3_col11 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_12050_row3_col13 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_12050_row4_col0, #T_12050_row9_col0 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_12050_row4_col1, #T_12050_row7_col5, #T_12050_row8_col6 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_12050_row4_col2 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_12050_row4_col5 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_12050_row4_col7, #T_12050_row5_col7 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_12050_row4_col9, #T_12050_row6_col13 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_12050_row4_col10, #T_12050_row10_col2 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_12050_row4_col11 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_12050_row4_col12 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_12050_row5_col1, #T_12050_row6_col8 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_12050_row5_col3, #T_12050_row5_col13 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_12050_row5_col4, #T_12050_row6_col1 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_12050_row5_col6, #T_12050_row11_col6 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_12050_row5_col8 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_12050_row5_col10, #T_12050_row6_col9, #T_12050_row12_col0 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_12050_row5_col11, #T_12050_row11_col8 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_12050_row5_col12, #T_12050_row6_col11 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_12050_row6_col0, #T_12050_row8_col10, #T_12050_row9_col4 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_12050_row6_col2, #T_12050_row11_col1 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_12050_row6_col3 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_12050_row6_col4, #T_12050_row7_col8 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_12050_row6_col10 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_12050_row7_col3 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_12050_row7_col4 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_12050_row7_col10 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_12050_row7_col11, #T_12050_row10_col8 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_12050_row7_col13 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_12050_row8_col1 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_12050_row8_col5 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_12050_row8_col7 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_12050_row8_col9 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_12050_row8_col11 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_12050_row8_col12 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_12050_row9_col1, #T_12050_row9_col3, #T_12050_row12_col10 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_12050_row9_col5, #T_12050_row9_col6 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_12050_row9_col7 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_12050_row9_col8 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_12050_row9_col11 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_12050_row9_col13 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_12050_row10_col1 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_12050_row10_col3, #T_12050_row10_col5 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_12050_row10_col4 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_12050_row10_col6, #T_12050_row11_col5 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }

# %% [markdown]
# # Rede neural

# %%
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# ## Dividir atributos e saída

# %%
X=Train_Data[Train_Data.columns[Train_Data.columns!='target']]
X.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal
# 0   0     1
# 1   0     2
# 2   0     2
# 3   0     2
# 4   0     2

# %%
Y=Train_Data['target']

# %% [markdown]
# ## Dividir treinamento e teste

# %%
train_x, test_x, train_y,test_y=train_test_split(X,Y,random_state=0,test_size=0.2)
print(train_y.shape, test_y.shape)
# Out:
# (241,) (61,)

# %% [markdown]
# ## Rede neural multicamadas sklearn

# %%
def MLP(train_x, train_y, test_x, test_y, n_neurons):
    reg = MLPClassifier(hidden_layer_sizes=(n_neurons,n_neurons,n_neurons), activation="relu" ,random_state=1, max_iter=200).fit(train_x, train_y)
    y_pred=reg.predict(test_x)

    model_accuracy = round(accuracy_score(test_y, y_pred),2)
    #confusion matrix
    cm = confusion_matrix(test_y, y_pred)
    return model_accuracy,cm, y_pred

# %%
accuracy,conf_marix,y_pred = MLP(train_x, train_y, test_x, test_y, 512)
print("Model Accuracy:" + str(accuracy) + "\n" + "Confusion Matrix:\n" + str(conf_marix))
# Out:
# Model Accuracy:0.8
# Confusion Matrix:
# [[21  6]
#  [ 6 28]]

# %%
def error_plot(train_x, train_y, test_x, test_y):

    error = []
    # Calculando o erro variando o número de neurônios, incrementando em base 2 (16,32,64,128,256 e 512)
    n_neurons = 16
    while n_neurons <=512:
        accuracy,conf_marix,y_pred = MLP(train_x, train_y, test_x ,test_y, n_neurons)
        error.append(np.mean(y_pred != test_y))
        n_neurons *= 2

    plt.figure(figsize=(12, 6))
    plt.plot(error, color='red', linestyle='dashed', marker='o',
             markerfacecolor='blue', markersize=10)
    plt.title('Error Rate Neurons Quantity')
    plt.xlabel('Neurons Quantity')
    plt.ylabel('Mean Error')

# %%
error_plot(train_x, train_y, test_x, test_y)
# Out:
# c:\Users\talmeidar\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# ## Rede neural multicamadas keras

# %%
train_x.shape
# Out:
# (241, 13)

# %%
def NN(train_x, train_y, test_x, test_y, n_neurons):
    
    tf.random.set_seed(2)
    
    new_train_x, x_val, new_train_y, y_val = train_test_split(train_x, train_y, test_size = 0.2, random_state = 13)

    NN_model = keras.Sequential([
    keras.layers.Dense(n_neurons, activation='relu', input_shape=(None, 241, 13)),
    keras.layers.Dense(n_neurons, activation='relu'),
    keras.layers.Dense(n_neurons, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
    ])
    
    NN_model.compile(
    loss='binary_crossentropy',
    optimizer='adamax',
    metrics=['accuracy']
    )
    
    
    train_history = NN_model.fit(
    new_train_x, new_train_y,
    validation_data=(x_val, y_val),
    batch_size = 8,
    shuffle=True,
    epochs = 30,
    verbose = 0
    )
    
    pred_es = NN_model.predict(test_x)
    pred_novo = [np.round(i[0]) for i in pred_es]
    results = NN_model.evaluate(test_x, test_y)
    accuracy = accuracy_score(test_y, pred_novo)
    cm = confusion_matrix(test_y, pred_novo)

    return results, accuracy, cm, train_history, pred_es

# %%
results, accuracy, cm, train_history, pred_es = NN(train_x, train_y, test_x, test_y, 512)
print("\nModel Accuracy:" + str(round(results[1], 2)))
print("\nModel Accuracy:" + str(round(accuracy, 2)))
print("\nConfusion Marix:\n" + str(cm))
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, None, 241, 13) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 241, 13), dtype=tf.float32, name='dense_16_input'), name='dense_16_input', description="created by layer 'dense_16_input'"), but it was called on an input with incompatible shape (8, 13).
# WARNING:tensorflow:Model was constructed with shape (None, None, 241, 13) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 241, 13), dtype=tf.float32, name='dense_16_input'), name='dense_16_input', description="created by layer 'dense_16_input'"), but it was called on an input with incompatible shape (8, 13).
# WARNING:tensorflow:Model was constructed with shape (None, None, 241, 13) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 241, 13), dtype=tf.float32, name='dense_16_input'), name='dense_16_input', description="created by layer 'dense_16_input'"), but it was called on an input with incompatible shape (None, 13).
# WARNING:tensorflow:Model was constructed with shape (None, None, 241, 13) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 241, 13), dtype=tf.float32, name='dense_16_input'), name='dense_16_input', description="created by layer 'dense_16_input'"), but it was called on an input with incompatible shape (None, 13).
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001CD983AC1F0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5644 - accuracy: 0.7541
#
# Model Accuracy:0.75
#
# Model Accuracy:0.75
#
# Confusion Marix:
# [[20  7]
#  [ 8 26]]

# %%
def accuracy_plot(train_x, train_y, test_x, test_y):

    accuracy = []

    # Calculando o erro variando o número de neurônios, incrementando em base 2 (16,32,64,128,256 e 512)
    n_neurons = 16
    while n_neurons <=512:
    
        results = NN(train_x, train_y, test_x, test_y, n_neurons)
        accuracy.append(np.mean(results[1]))
        n_neurons *= 2
        
        
    plt.figure(figsize=(12, 6))
    plt.plot(accuracy, color='red', linestyle='dashed', marker='o',
             markerfacecolor='blue', markersize=10)
    plt.title('Accuracy Rate Neurons Quantity')
    plt.xlabel('Neurons Quantity')
    plt.ylabel('Mean Accuracy')

# %%
accuracy_plot(train_x, train_y, test_x, test_y)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, None, 241, 13) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 241, 13), dtype=tf.float32, name='dense_20_input'), name='dense_20_input', description="created by layer 'dense_20_input'"), but it was called on an input with incompatible shape (8, 13).
# WARNING:tensorflow:Model was constructed with shape (None, None, 241, 13) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 241, 13), dtype=tf.float32, name='dense_20_input'), name='dense_20_input', description="created by layer 'dense_20_input'"), but it was called on an input with incompatible shape (8, 13).
# WARNING:tensorflow:Model was constructed with shape (None, None, 241, 13) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 241, 13), dtype=tf.float32, name='dense_20_input'), name='dense_20_input', description="created by layer 'dense_20_input'"), but it was called on an input with incompatible shape (None, 13).
# WARNING:tensorflow:Model was constructed with shape (None, None, 241, 13) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 241, 13), dtype=tf.float32, name='dense_20_input'), name='dense_20_input', description="created by layer 'dense_20_input'"), but it was called on an input with incompatible shape (None, 13).
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001CD9A8FA8B0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6955 - accuracy: 0.5902
# WARNING:tensorflow:Model was constructed with shape (None, None, 241, 13) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 241, 13), dtype=tf.float32, name='dense_24_input'), name='dense_24_input', description="created by layer 'dense_24_input'"), but it was called on an input with incompatible shape (8, 13).
# WARNING:tensorflow:Model was constructed with shape (None, None, 241, 13) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 241, 13), dtype=tf.float32, name='dense_24_input'), name='dense_24_input', description="created by layer 'dense_24_input'"), but it was called on an input with incompatible shape (8, 13).
# WARNING:tensorflow:Model was constructed with shape (None, None, 241, 13) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 241, 13), dtype=tf.float32, name='dense_24_input'), name='dense_24_input', description="created by layer 'dense_24_input'"), but it was called on an input with incompatible shape (None, 13).
# WARNING:tensorflow:Model was constructed with shape (None, None, 241, 13) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 241, 13), dtype=tf.float32, name='dense_24_input'), name='dense_24_input', description="created by layer 'dense_24_input'"), but it was called on an input with incompatible shape (None, 13).
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5710 - accuracy: 0.7213
# WARNING:tensorflow:Model was constructed with shape (None, None, 241, 13) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 241, 13), dtype=tf.float32, name='dense_28_input'), name='dense_28_input', description="created by layer 'dense_28_input'"), but it was called on an input with incompatible shape (8, 13).
# WARNING:tensorflow:Model was constructed with shape (None, None, 241, 13) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 241, 13), dtype=tf.float32, name='dense_28_input'), name='dense_28_input', description="created by layer 'dense_28_input'"), but it was called on an input with incompatible shape (8, 13).
# WARNING:tensorflow:Model was constructed with shape (None, None, 241, 13) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 241, 13), dtype=tf.float32, name='dense_28_input'), name='dense_28_input', description="created by layer 'dense_28_input'"), but it was called on an input with incompatible shape (None, 13).
# WARNING:tensorflow:Model was constructed with shape (None, None, 241, 13) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 241, 13), dtype=tf.float32, name='dense_28_input'), name='dense_28_input', description="created by layer 'dense_28_input'"), but it was called on an input with incompatible shape (None, 13).
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5170 - accuracy: 0.7213
# WARNING:tensorflow:Model was constructed with shape (None, None, 241, 13) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 241, 13), dtype=tf.float32, name='dense_32_input'), name='dense_32_input', description="created by layer 'dense_32_input'"), but it was called on an input with incompatible shape (8, 13).
# WARNING:tensorflow:Model was constructed with shape (None, None, 241, 13) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 241, 13), dtype=tf.float32, name='dense_32_input'), name='dense_32_input', description="created by layer 'dense_32_input'"), but it was called on an input with incompatible shape (8, 13).
# WARNING:tensorflow:Model was constructed with shape (None, None, 241, 13) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 241, 13), dtype=tf.float32, name='dense_32_input'), name='dense_32_input', description="created by layer 'dense_32_input'"), but it was called on an input with incompatible shape (None, 13).
# WARNING:tensorflow:Model was constructed with shape (None, None, 241, 13) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 241, 13), dtype=tf.float32, name='dense_32_input'), name='dense_32_input', description="created by layer 'dense_32_input'"), but it was called on an input with incompatible shape (None, 13).
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5907 - accuracy: 0.7213
# WARNING:tensorflow:Model was constructed with shape (None, None, 241, 13) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 241, 13), dtype=tf.float32, name='dense_36_input'), name='dense_36_input', description="created by layer 'dense_36_input'"), but it was called on an input with incompatible shape (8, 13).
# WARNING:tensorflow:Model was constructed with shape (None, None, 241, 13) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 241, 13), dtype=tf.float32, name='dense_36_input'), name='dense_36_input', description="created by layer 'dense_36_input'"), but it was called on an input with incompatible shape (8, 13).
# WARNING:tensorflow:Model was constructed with shape (None, None, 241, 13) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 241, 13), dtype=tf.float32, name='dense_36_input'), name='dense_36_input', description="created by layer 'dense_36_input'"), but it was called on an input with incompatible shape (None, 13).
# WARNING:tensorflow:Model was constructed with shape (None, None, 241, 13) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 241, 13), dtype=tf.float32, name='dense_36_input'), name='dense_36_input', description="created by layer 'dense_36_input'"), but it was called on an input with incompatible shape (None, 13).
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5993 - accuracy: 0.7377
# WARNING:tensorflow:Model was constructed with shape (None, None, 241, 13) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 241, 13), dtype=tf.float32, name='dense_40_input'), name='dense_40_input', description="created by layer 'dense_40_input'"), but it was called on an input with incompatible shape (8, 13).
# WARNING:tensorflow:Model was constructed with shape (None, None, 241, 13) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 241, 13), dtype=tf.float32, name='dense_40_input'), name='dense_40_input', description="created by layer 'dense_40_input'"), but it was called on an input with incompatible shape (8, 13).
# WARNING:tensorflow:Model was constructed with shape (None, None, 241, 13) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 241, 13), dtype=tf.float32, name='dense_40_input'), name='dense_40_input', description="created by layer 'dense_40_input'"), but it was called on an input with incompatible shape (None, 13).
# WARNING:tensorflow:Model was constructed with shape (None, None, 241, 13) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 241, 13), dtype=tf.float32, name='dense_40_input'), name='dense_40_input', description="created by layer 'dense_40_input'"), but it was called on an input with incompatible shape (None, 13).
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5644 - accuracy: 0.7541

# %% [markdown]
# # Normalizando os dados

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(train_x)
X_test_scaled = scaler.fit_transform(test_x)

# %% [markdown]
# # Visualizando normalização

# %%
fig, ax = plt.subplots(ncols=3, figsize=(15,5))
sns.distplot(np.concatenate(X.values), ax=ax[0]).set_title('Original Data')
sns.distplot(np.concatenate(X_train_scaled), ax=ax[1]).set_title('Train Scaled Data')
sns.distplot(np.concatenate(X_test_scaled), ax=ax[2]).set_title('Test Scaled Data')
plt.tight_layout
plt.show()
# Out:
# c:\Users\talmeidar\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\talmeidar\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\talmeidar\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Redes neurais

# %%
accuracy,conf_marix,y_pred = MLP(X_train_scaled, train_y, X_test_scaled ,test_y,64)
print("Model Accuracy:" + str(accuracy) + "\n" + "Confusion Matrix:\n" + str(conf_marix))
# Out:
# Model Accuracy:0.84
# Confusion Matrix:
# [[22  5]
#  [ 5 29]]

# %%
results, accuracy, cm, train_history, pred_es = NN(X_train_scaled, train_y, X_test_scaled ,test_y,64)
print("\nModel Accuracy:" + str(round(results[1], 2)))
print("\nModel Accuracy:" + str(round(accuracy, 2)))
print("\nConfusion Marix:\n" + str(cm))
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, None, 241, 13) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 241, 13), dtype=tf.float32, name='dense_44_input'), name='dense_44_input', description="created by layer 'dense_44_input'"), but it was called on an input with incompatible shape (8, 13).
# WARNING:tensorflow:Model was constructed with shape (None, None, 241, 13) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 241, 13), dtype=tf.float32, name='dense_44_input'), name='dense_44_input', description="created by layer 'dense_44_input'"), but it was called on an input with incompatible shape (8, 13).
# WARNING:tensorflow:Model was constructed with shape (None, None, 241, 13) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 241, 13), dtype=tf.float32, name='dense_44_input'), name='dense_44_input', description="created by layer 'dense_44_input'"), but it was called on an input with incompatible shape (None, 13).
# WARNING:tensorflow:Model was constructed with shape (None, None, 241, 13) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 241, 13), dtype=tf.float32, name='dense_44_input'), name='dense_44_input', description="created by layer 'dense_44_input'"), but it was called on an input with incompatible shape (None, 13).
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3303 - accuracy: 0.9180
#
# Model Accuracy:0.92
#
# Model Accuracy:0.92
#
# Confusion Marix:
# [[24  3]
#  [ 2 32]]

# %% [markdown]
# # Random Forest

# %%
model_rf = RandomForestClassifier(n_estimators=100, random_state=42)
model_rf.fit(X_train_scaled, train_y)
y_pred_rf = model_rf.predict(X_test_scaled)

print('Acurácia:' + str(round(accuracy_score(test_y, y_pred_rf),2)))
print(classification_report(test_y, y_pred_rf))
# Out:
# Acurácia:0.87
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86        27
#            1       0.91      0.85      0.88        34
#
#     accuracy                           0.87        61
#    macro avg       0.87      0.87      0.87        61
# weighted avg       0.87      0.87      0.87        61

# %% [markdown]
# # XGBoost

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier()
xgb.fit(X_train_scaled, train_y)
# Out:
# [15:09:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# c:\Users\talmeidar\Anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=8,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
#Predizendo dados 
y_pred = xgb.predict(X_test_scaled)

#Verificando modelo
print('Acurácia:' + str(round(accuracy_score(test_y, y_pred),2)))
print(classification_report(test_y, y_pred))
# Out:
# Acurácia:0.82
#               precision    recall  f1-score   support
#
#            0       0.77      0.85      0.81        27
#            1       0.87      0.79      0.83        34
#
#     accuracy                           0.82        61
#    macro avg       0.82      0.82      0.82        61
# weighted avg       0.82      0.82      0.82        61

# %%
feature_names = train_x.columns

# %%
xgb.get_booster().feature_names = list(feature_names.values)

# %%
xgb.get_booster().feature_names
# Out:
# ['age',
#  'sex',
#  'cp',
#  'trestbps',
#  'chol',
#  'fbs',
#  'restecg',
#  'thalach',
#  'exang',
#  'oldpeak',
#  'slope',
#  'ca',
#  'thal']

# %%
from xgboost import plot_importance

# %%
plot_importance(xgb)
plt.show()

# %%
features = train_x.columns
importances = model_rf.feature_importances_
indices = np.argsort(importances)

plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()
